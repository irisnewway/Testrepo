# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Aolin Zhao**
# Project Manager

# %% [markdown]
# *I am interested in data science because it's getting more and more important for decision-makings in business world.*

# %% [markdown]
# ### Simple Calculation in Swedish

# %%
Ett = 1
Två = 2
print (Ett + Två)
# Out:
# 3

# %% [markdown]
# ### Bring a pet to Sweden
# >“Until one has loved an animal, a part of one’s soul remains unawakened.” — Anatole France
# 1. The animal must be ID-marked.
# 2. The animal must have a valid vaccination against rabies.
# 3. The animal must have an EU-passport for pets (animal travelling from an EU-related country which do not issue passports should travel with form E9.207 instead)
# 4. The animal must be reported to customs when passing the border.
#
# *Above information comes from* [Bring a pet to Sweden](https://www.swedenabroad.se/en/about-sweden-non-swedish-citizens/latvia/going-to-sweden/bring-a-pet-to-sweden/)
